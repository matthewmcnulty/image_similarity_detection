# %%
import numpy as np
import pandas as pd
import glob
import os

# %%
images_BOYNER = os.listdir('/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/BOYNER')
images_MODANISA = os.listdir('/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/MODANISA')
images_MUDO = os.listdir('/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/MUDO')
images_YARGICI = os.listdir('/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/YARGICI')

# %%
#BOYNER
images_BOYNER = glob.glob("/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/BOYNER/*.jpg")
images_BOYNER.sort(key=os.path.getmtime)
images_BOYNER = [i.replace('/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/BOYNER/', '') for i in images_BOYNER]
images_BOYNER.reverse()
print("\n".join(images_BOYNER))
# Out:
# 2ecf6b6269d927dbf3ede6361eeec0c0ac885a52.jpg
# 4906f360fa975fcddd53697be1c1fbda95cc1cc4.jpg
# 07051e47a4173a3c7ec74e6e61d40c88732e6ce3.jpg
# 91c0aaf72115b00606c1778521f2098e0081fc5d.jpg
# dfdce993da44b78c21f9c4004f19dc4e0501a7d6.jpg
# 15f032077519af7171443ca8dedf125355b4788e.jpg
# ead1fc088e2315096ed0e3265b2ac85001335563.jpg
# 195abadd6a50a2e14bea03c7312d2a3b0721f956.jpg
# 799725283e0da668bec455304c63a2874d981c53.jpg
# 96db367512fad545e56718000e453a048e83d007.jpg
# 50423d15a3feb7222fc0ed7783d672dddb293554.jpg
# b68382ebe9e6ae4391ce6b949132cee105848e60.jpg
# 4e460b58cba38028bd8a8b53cdb319aa95be887e.jpg
# 7319e5fdabacfb74481d1640cb92f28314e73479.jpg
# 19830878e0be84b14045899b0c3de9191ce1ad6d.jpg
# 61e26ee48e77558b736414691ef3caf4664c06f3.jpg
# c4c4d1aadfd865f00a9844f06837a13566b4fa1e.jpg
# 472a1731d05d9e96a79451e9b3e63ce389ec28dc.jpg
# 08238ae35a002c0ebf1ed223d3f77d6916707ae1.jpg
# d98a4818a97663d4931d00587c4618873cb4e69c.jpg
# 329490aaa3380cb9edb464317e1fb6f6f995c695.jpg
# ...

# %%
#MODANISA
images_MODANISA = glob.glob("/home/anm/image_similarity_detection/fashion_web_scraping//images_scraped/full/MODANISA/*.jpg")
images_MODANISA.sort(key=os.path.getmtime)
images_MODANISA = [i.replace('/home/anm/image_similarity_detection/fashion_web_scraping//images_scraped/full/MODANISA/', '') for i in images_MODANISA]
images_MODANISA.reverse()
print("\n".join(images_MODANISA))
# Out:
# c76f5c8e2c20b7c04465d6aa1d6d39d9601ed9c7.jpg
# c8057eac4a7ed234ca32c250547e4d9b30f530e0.jpg
# 61d4f35c880989c542749b358eb777b15c738881.jpg
# f365f3f1c3ebc1c430ce68d16268e8e42e56cea3.jpg
# ce97d37546699e51f9cdaac0c1b8ab8dc55e8754.jpg
# 6e6b0ceec78d49a427cb2ae11bad4677154979ca.jpg
# e8fc899b856eac55e47c7c00c0e0419a45126525.jpg
# aed8dd98cd4a3cb6571477531d468984142542f8.jpg
# 39e12b7ee234d9ab992ca79903a81dd4ca193dad.jpg
# 876e4d4f035ea94531f0722b4e440ecd538025d6.jpg
# 726dca1d637ac86dfbd11ebd9789f3f5e69e2493.jpg
# 63af2f9d8490876dc7cc1d3ca12292972ab37922.jpg
# f8fc93a86fd67cc6054756530be59ed35ecb1192.jpg
# 0e823ed94d22e9a6dcdc0022185dd92328fa3f30.jpg
# b33b5871c5b7214d1d5a167a3c19dbc81e0f837c.jpg
# b50d2254fb2ebddabe0922628a8e0a8466d5c76b.jpg
# b5a77d6c024ba8909e94e6c8ab25e97766ab68a6.jpg
# d35847aba1b871ce98a9e52e4514f30221d76e7a.jpg
# 68ec41180fc3d6c555e0280f52e7ce478230cd83.jpg
# 158eaadfc998f91fbabf9a4090f4c497eb45ef4a.jpg
# 346f3cea6dce4edca5216206e252ffb59210b553.jpg
# ...

# %%
#MUDO
images_MUDO = glob.glob("/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/MUDO/*.jpg")
images_MUDO.sort(key=os.path.getmtime)
images_MUDO = [i.replace('/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/MUDO/', '') for i in images_MUDO]
images_MUDO.reverse()
print("\n".join(images_MUDO))
# Out:
# 93aeb868616a72b2ec8866b5e88ec268d064aede.jpg
# 6bac8405adb70bf523b92d84f121624ad24d1017.jpg
# 9307cbd47d563ad9b266eb3bf0edfcb57eb40b84.jpg
# cd52c5b85bd028c95ecdd424386d8bf9035967fa.jpg
# a7fcd07c5a99c4b0136e9429f530081c63b2fe9c.jpg
# 2ffa5113e6233990864ceb0be3b7076c65124803.jpg
# f806472a2de8ace31e483c7a121c5864369524b4.jpg
# d64dc73620f4255bced4df50afe0e630b3f2a4ca.jpg
# 31b96443a9859e5b2aff50b6ebc7ba358bd4c41f.jpg
# daadbcc46f74cbaceb08443c706608ef78751993.jpg
# a0fb28092ae1ff66bdccdf16782cb1618876f90a.jpg
# dcc19b341d7a54c36f1ce35dc96ee021c7f9c3b8.jpg
# dac7e75db8cb7054d6f788bbe4c078ae29ea5ac8.jpg
# a529a176977456d9b61348fba5e93056a6d2fa38.jpg
# c16875a9eac5ba5c06c3e87081defbf741947f18.jpg
# 8b5d939958294404eb204bd966080cc29d97e92a.jpg
# 92dcd6f55cb0a61d4bc17a9cf40cf772d5e767dc.jpg
# ae77c9733c6c9e7c27d64ea3ba83d2fbe3a765d0.jpg
# c07eb5f5e74d58c18f7ddf53b9f0627a18b4a107.jpg
# 5d270453cce007d14a88ef135e409c5e3e8dff95.jpg
# e36b89ffcc326aff20dad23eb0577d04b48fbeed.jpg
# ...

# %%
#YARGICI
images_YARGICI = glob.glob("/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/YARGICI/*.jpg")
images_YARGICI.sort(key=os.path.getmtime)
images_YARGICI = [i.replace('/home/anm/image_similarity_detection/fashion_web_scraping/images_scraped/full/YARGICI/', '') for i in images_YARGICI]
images_YARGICI.reverse()
print("\n".join(images_YARGICI))
# Out:
# 17ec00404e74e027f28346fbd92c335c6fca9b28.jpg
# 49ed7f4e4725000efb9b0fd9f8367642b466e944.jpg
# 7aa4c52e549e3d76c04953dbbd0a47646f35651e.jpg
# 6111c3861227019a4292f1012c2d28ddd2d24779.jpg
# 4c084ce6f1555a7b47fdc7384b262694737c45cc.jpg
# 2ac0394e753ff03414b5085db09c69200a3d8c71.jpg
# 8c0a246e4ace091576879a38a896b9bc10b7136a.jpg
# 3b4efca8492b734bcc39df1f8cc128d4b6bef4d9.jpg
# be46a73f92a9dd1c9d8952908fe717491f0807df.jpg
# 5e245da6fc17f77b8ef25f9a502532ec5ab66e41.jpg
# f4a804fad34b050618a4d751d0e6a89472ca91e0.jpg
# e3d8551add732a10b6b5a7387f028ef329a9e70e.jpg
# b77b5df61b770295541c1f6f067a438138ada0c4.jpg
# c1234b35173e3d9d528a066807425d2815e355b8.jpg
# e740704ca15a468ce5921998677d0221183ed3bc.jpg
# e5a334240f48b50f9105033abe14ed3120290544.jpg
# 33348c5db51ae46af694d167a242aac285c2fbaf.jpg
# 7ea9e0a425d259b91a2c87b7be0b2f5f497bb11f.jpg
# 88205bb4b79eaa1291b639223789e5deaa98826f.jpg
# 655dc6a9469729877d02d5a661dfed9ac971cf96.jpg
# e2494ba53b6b301f0d3d93a196cf5005affd4213.jpg
# ...

# %%
print(len(images_BOYNER))
print(len(images_MODANISA))
print(len(images_MUDO))
print(len(images_YARGICI))
# Out:
# 90
# 117
# 107
# 34

# %%
lst1 = [*images_BOYNER, *images_MODANISA]
print(len(lst1))

df1 = pd.DataFrame({'imageName': lst1})
df1
# Out:
# 207
#                                         imageName
# 0    2ecf6b6269d927dbf3ede6361eeec0c0ac885a52.jpg
# 1    4906f360fa975fcddd53697be1c1fbda95cc1cc4.jpg
# 2    07051e47a4173a3c7ec74e6e61d40c88732e6ce3.jpg
# 3    91c0aaf72115b00606c1778521f2098e0081fc5d.jpg
# 4    dfdce993da44b78c21f9c4004f19dc4e0501a7d6.jpg
# ..                                            ...
# 202  184891a839127e8a8af5cfb5452d55c16d9f01ad.jpg
# 203  94f05fa5806755760f83ee39bf22999d0bf57c52.jpg
# 204  d25747e267f64c45cc1c0adc978f4893de016414.jpg
# 205  3b6a9a6f4edb20bcf2ccd27e93e518e7a39f7ddc.jpg
# 206  b4510c039c0acbb881deadbb2b2aa358cb7df706.jpg
#
# [207 rows x 1 columns]

# %%
finaldata_BOYNER = pd.read_json (r'/home/anm/image_similarity_detection/fashion_web_scraping/jsonFiles/finaldata_BOYNER.json')
finaldata_MODANISA = pd.read_json (r'/home/anm/image_similarity_detection/fashion_web_scraping/jsonFiles/finaldata_MODANISA.json')
finaldata_MUDO = pd.read_json (r'/home/anm/image_similarity_detection/fashion_web_scraping/jsonFiles/finaldata_MUDO.json')
finaldata_YARGICI = pd.read_json (r'/home/anm/image_similarity_detection/fashion_web_scraping/jsonFiles/finaldata_YARGICI.json')

# %%
productId_BOYNER = finaldata_BOYNER['productId']
productId_BOYNER = pd.Series(list(reversed(productId_BOYNER)))

productId_MODANISA = finaldata_MODANISA['productId']
productId_MODANISA = pd.Series(list(reversed(productId_MODANISA)))

productId_MUDO = finaldata_MUDO['productId']
productId_MUDO = pd.Series(list(reversed(productId_MUDO)))

productId_YARGICI = finaldata_YARGICI['productId']
productId_YARGICI = pd.Series(list(reversed(productId_YARGICI)))

# %%
imageLink_BOYNER = finaldata_BOYNER['imageLink']
imageLink_BOYNER = pd.Series(list(reversed(imageLink_BOYNER)))

imageLink_MODANISA = finaldata_MODANISA['imageLink']
imageLink_MODANISA = pd.Series(list(reversed(imageLink_MODANISA)))

imageLink_MUDO = finaldata_MUDO['imageLink']
imageLink_MUDO = pd.Series(list(reversed(imageLink_MUDO)))

imageLink_YARGICI = finaldata_YARGICI['imageLink']
imageLink_YARGICI = pd.Series(list(reversed(imageLink_YARGICI)))

# %%
json_BOYNER = pd.DataFrame({'productId': productId_BOYNER,
                           'imageLink': imageLink_BOYNER})
json_MODANISA = pd.DataFrame({'productId': productId_MODANISA,
                           'imageLink': imageLink_MODANISA})
json_MUDO = pd.DataFrame({'productId': productId_MUDO,
                           'imageLink': imageLink_MUDO})
json_YARGICI = pd.DataFrame({'productId': productId_YARGICI,
                           'imageLink': imageLink_YARGICI})

# %%
print(len(json_BOYNER))
print(len(json_MODANISA))
print(len(json_MUDO))
print(len(json_YARGICI))
# Out:
# 90
# 118
# 120
# 34

# %%
pd.set_option('max_colwidth', 100)

def make_clickable(val):
    return '<a href="{}">{}</a>'.format(val,val)

# %%
#json_BOYNER.style.format(make_clickable)
#json_MODANISA.style.format(make_clickable)
#json_MUDO.style.format(make_clickable)
#json_YARGICI.style.format(make_clickable)

# %%
from IPython.core.display import HTML

# Converting links to html tags
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

# %%
HTML(json_BOYNER.to_html(escape=False,formatters=dict(imageLink=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>productId</th>
#       <th>imageLink</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>882346</td>
#       <td><img src="https://statics.boyner.com.tr/mnresize/325/451/productimages/5002454467_034_01.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>882428</td>
#       <td><img src="https://statics.boyner.com.tr/mnresize/325/451/productimages/5002461521_001_01.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>879209</td>
#       <td><img src="https://statics.boyner.com.tr/mnresize/325/451/productimages/5002464265_600_01.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>879219</td>
#       <td><img src="https://statics.boyner.com.tr/mnresize/325/451/productimages/5002464287_001_10.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
# Extra images that are to be removed..
# BOYNER = Remove: none, Rotate: 7/8, 68/69. Done
# MODANISA = Remove: 54, Rotate: 103/104, 115/116. Done
# MUDO = Remove: , Rotate: THIS ONE IS COMPLETELY MESSED UP!
# YARGICI = Remove: , Rotate: SO IS THIS ONE!

# %%
# BOYNER
#json_BOYNER = json_BOYNER.drop([json_BOYNER.index[]])
#json_BOYNER = json_BOYNER.reset_index(drop=True)

#temp = json_BOYNER.iloc[68]
#json_BOYNER.iloc[68] = json_BOYNER.iloc[69]
#json_BOYNER.iloc[69] = temp

# %%
# MODANISA
#json_MODANISA = json_MODANISA.drop([json_MODANISA.index[54]])
#json_MODANISA = json_MODANISA.reset_index(drop=True)

#temp = json_MODANISA.iloc[103]
#json_MODANISA.iloc[103] = json_MODANISA.iloc[104]
#json_MODANISA.iloc[104] = temp

# %%
# MUDO not done
#json_MUDO = json_MUDO.drop([json_MUDO.index[]])
#json_MUDO = json_MUDO.reset_index(drop=True)

# order = '5', '7', '3', '31', '27', '9', '2', '17', '6', '0', '28',
#         '1', '25', '19', '4', '16', '18', '23', '33', '12', '8', '24', 
#         '30', '21', '13', '29', '32', '11', '15', '26', '20', '14', '10', 
#         '22'

# %%
# YARGICI not done
#json_YARGICI = json_YARGICI.drop([json_YARGICI.index[]])
#json_YARGICI = json_YARGICI.reset_index(drop=True)

# order = '5', '7', '3', '31', '27', '9', '2', '17', '6', '0', '28',
#         '1', '25', '19', '4', '16', '18', '23', '33', '12', '8', '24', 
#         '30', '21', '13', '29', '32', '11', '15', '26', '20', '14', '10', 
#         '22'

# %%
# Stack the DataFrames on top of each other
df2 = pd.concat([json_BOYNER, json_MODANISA], axis=0)
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#      productId
# 0       882346
# 1       882428
# 2       879209
# 3       879219
# 4       879776
# ..         ...
# 202    1830257
# 203    1419393
# 204    1339205
# 205    1768209
# 206    1486100
#
# [207 rows x 1 columns]

# %%
df1
# Out:
#                                         imageName
# 0    2ecf6b6269d927dbf3ede6361eeec0c0ac885a52.jpg
# 1    4906f360fa975fcddd53697be1c1fbda95cc1cc4.jpg
# 2    07051e47a4173a3c7ec74e6e61d40c88732e6ce3.jpg
# 3    91c0aaf72115b00606c1778521f2098e0081fc5d.jpg
# 4    dfdce993da44b78c21f9c4004f19dc4e0501a7d6.jpg
# ..                                            ...
# 202  184891a839127e8a8af5cfb5452d55c16d9f01ad.jpg
# 203  94f05fa5806755760f83ee39bf22999d0bf57c52.jpg
# 204  d25747e267f64c45cc1c0adc978f4893de016414.jpg
# 205  3b6a9a6f4edb20bcf2ccd27e93e518e7a39f7ddc.jpg
# 206  b4510c039c0acbb881deadbb2b2aa358cb7df706.jpg
#
# [207 rows x 1 columns]

# %%
#del df2['imageLink']
#df2['productId']= df2['productId'].map(str)
df2
# Out:
#     productId
# 0      882346
# 1      882428
# 2      879209
# 3      879219
# 4      879776
# ..        ...
# 202   1830257
# 203   1419393
# 204   1339205
# 205   1768209
# 206   1486100
#
# [207 rows x 1 columns]

# %%
# Place the DataFrames side by side
image_data = pd.concat([df1, df2], axis=1)
type(image_data)
# Out:
# pandas.core.frame.DataFrame

# %%
import json

result = image_data.to_json(orient="records")
parsed = json.loads(result)

with open('image_data.json', 'w') as json_file:
    json.dump(parsed, json_file)

# %%
# remove .jpg from df1
